# %% [markdown]
# # ByteTrack Model

# %% [markdown]
# ### Imports

# %%
import cv2
import time
import numpy as np
from pathlib import Path
from ultralytics import YOLO
import supervision as sv
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Admin\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ### config

# %%
# Paths 
WEIGHTS_PATH = r"C:\Users\Admin\path\to\your\best.pt"
SOURCE       = r"C:\Users\Admin\path\to\your\video.mp4"
OUTPUT_DIR   = r"C:\Users\Admin\path\to\output"

# Detection config 
CONF_THRESHOLD = 0.25 # minimum confidence to show a detection
IOU_THRESHOLD  = 0.45 # minimum IoU to consider two boxes as the same object
IMG_SIZE       = 640 # must match training size

# Class names based on data yaml file from BDD100K dataset

CLASS_NAMES = {
    0: "bike",
    1: "bus",
    2: "car",
    3: "motor",
    4: "person",
    5: "rider",
    6: "traffic light",
    7: "traffic sign",
    8: "truck"
}
