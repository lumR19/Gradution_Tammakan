# %% [markdown]
# Using colab to train the model, we then get the best wights and test the model using it. here we conducted multiple tests using diffrent versions of the model wights.

# %% [markdown]
# ## YOLO Model Testing

# %% [markdown]
# ### Imports

# %%
from ultralytics import YOLO
from pathlib import Path
import time

# %% [markdown]
# ### Test 1
# best wights from 20 epochs
# MAp50:

# %% [markdown]
# ### Paths

# %%
# Path to best.pt downloaded from Colab/Drive
WEIGHTS_PATH = r"C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_runs\yolo11m_bdd100k_v1\weights\best.pt"

# Source: image file, video file, or a folder of images
SOURCE = r"C:\Users\samar\OneDrive\Desktop\Grad Project\Code\Datasets\Dashcam_clips\10_Sec_Clip.mp4"

# Output folder (annotated results saved here)
OUTPUT_DIR = r"C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_inference_results"

# %% [markdown]
# ### Config

# %%
CONF_THRESHOLD = 0.25   # minimum confidence to show a detection
IOU_THRESHOLD  = 0.45   # NMS threshold (suppress overlapping boxes)
IMG_SIZE       = 640    # must match training size

# %% [markdown]
# ### Inference

# %%
def run_inference():
    # Verify weights exist
    if not Path(WEIGHTS_PATH).exists():
        print(f"[ERROR] Weights not found: {WEIGHTS_PATH}")
        print("        Download best.pt from Google Drive first.")
        return

    if not Path(SOURCE).exists():
        print(f"[ERROR] Source not found: {SOURCE}")
        return

    print(f"Loading model : {WEIGHTS_PATH}")
    model = YOLO(WEIGHTS_PATH)

    print(f"Running inference on: {SOURCE}")
    print("(Running on CPU — video processing will be slower than real-time, that's expected)\n")

    start = time.time()

    results = model.predict(
        source    = SOURCE,
        imgsz     = IMG_SIZE,
        conf      = CONF_THRESHOLD,
        iou       = IOU_THRESHOLD,
        save      = True,               # saves annotated output
        project   = OUTPUT_DIR,
        name      = "run",
        save_txt  = True,               # also saves detections as .txt (useful later for analysis)
        save_conf = True,               # includes confidence scores in .txt files
        stream    = True,               # memory-efficient — important for long videos on CPU
        device    = "cpu",
        verbose   = False,
    )

    # Stream through results (required when stream=True)
    frame_count = 0
    for r in results:
        frame_count += 1

    elapsed = time.time() - start
    fps     = frame_count / elapsed if elapsed > 0 else 0

    print(f"\nDone!")
    print(f"  Frames processed : {frame_count}")
    print(f"  Time taken       : {elapsed:.1f}s")
    print(f"  Average FPS      : {fps:.2f}")
    print(f"  Output saved to  : {OUTPUT_DIR}/run/")


if __name__ == "__main__":
    run_inference()
# Out:
# Loading model : C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_runs\yolo11m_bdd100k_v1\weights\best.pt
# Running inference on: C:\Users\samar\OneDrive\Desktop\Grad Project\Code\Datasets\Dashcam_clips\10_Sec_Clip.mp4
# (Running on CPU — video processing will be slower than real-time, that's expected)
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[4], line 51
#
#      47     print(f"  Output saved to  : {OUTPUT_DIR}/run/")
#
#      50 if __name__ == "__main__":
#
# ---> 51     run_inference()
#
#
#
# Cell In[4], line 37, in run_inference()
#
#      35 # Stream through results (required when stream=True)
#
#      36 frame_count = 0
#
# ---> 37 for r in results:
#
#      38     frame_count += 1
#
#      40 elapsed = time.time() - start
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\_contextlib.py:61, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#
#      58         else:
#
#      59             # Pass the last request to the generator and get its response
#
#      60             with ctx_factory():
#
# ---> 61                 response = gen.send(request)
#
#      63 # We let the exceptions raised above by the generator's `.throw` or
#
#      64 # `.send` methods bubble up to our caller, except for StopIteration
#
#      65 except StopIteration as e:
#
#      66     # The generator informed us that it is done: take whatever its
#
#      67     # returned value (if any) was and indicate that we're done too
#
#      68     # by returning it (see docs for python's return-statement).
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:330, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#
#     328 # Inference
#
#     329 with profilers[1]:
#
# --> 330     preds = self.inference(im, *args, **kwargs)
#
#     331     if self.args.embed:
#
#     332         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:182, in BasePredictor.inference(self, im, *args, **kwargs)
#
#     176 """Run inference on a given image using the specified model and arguments."""
#
#     177 visualize = (
#
#     178     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#
#     179     if self.args.visualize and (not self.source_type.tensor)
#
#     180     else False
#
#     181 )
#
# --> 182 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1775 else:
#
# -> 1776     return self._call_impl(*args, **kwargs)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1783 # this function, and just call forward.
#
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1787     return forward_call(*args, **kwargs)
#
#    1789 result = None
#
#    1790 called_always_called_hooks = set()
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\autobackend.py:717, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#
#     715 # PyTorch
#
#     716 if self.pt or self.nn_module:
#
# --> 717     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#
#     719 # TorchScript
#
#     720 elif self.jit:
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1775 else:
#
# -> 1776     return self._call_impl(*args, **kwargs)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1783 # this function, and just call forward.
#
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1787     return forward_call(*args, **kwargs)
#
#    1789 result = None
#
#    1790 called_always_called_hooks = set()
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:142, in BaseModel.forward(self, x, *args, **kwargs)
#
#     140 if isinstance(x, dict):  # for cases of training and validating while training.
#
#     141     return self.loss(x, *args, **kwargs)
#
# --> 142 return self.predict(x, *args, **kwargs)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:159, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#
#     157 if augment:
#
#     158     return self._predict_augment(x)
#
# --> 159 return self._predict_once(x, profile, visualize, embed)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:181, in BaseModel._predict_once(self, x, profile, visualize, embed)
#
#     179 if profile:
#
#     180     self._profile_one_layer(m, x, dt)
#
# --> 181 x = m(x)  # run
#
#     182 y.append(x if m.i in self.save else None)  # save output
#
#     183 if visualize:
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1775 else:
#
# -> 1776     return self._call_impl(*args, **kwargs)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1783 # this function, and just call forward.
#
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1787     return forward_call(*args, **kwargs)
#
#    1789 result = None
#
#    1790 called_always_called_hooks = set()
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\modules\conv.py:89, in Conv.forward_fuse(self, x)
#
#      80 def forward_fuse(self, x):
#
#      81     """Apply convolution and activation without batch normalization.
#
#      82
#
#      83     Args:
#
#    (...)
#
#      87         (torch.Tensor): Output tensor.
#
#      88     """
#
# ---> 89     return self.act(self.conv(x))
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
#    1775 else:
#
# -> 1776     return self._call_impl(*args, **kwargs)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1783 # this function, and just call forward.
#
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1787     return forward_call(*args, **kwargs)
#
#    1789 result = None
#
#    1790 called_always_called_hooks = set()
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:553, in Conv2d.forward(self, input)
#
#     552 def forward(self, input: Tensor) -> Tensor:
#
# --> 553     return self._conv_forward(input, self.weight, self.bias)
#
#
#
# File c:\Users\samar\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\conv.py:548, in Conv2d._conv_forward(self, input, weight, bias)
#
#     535 if self.padding_mode != "zeros":
#
#     536     return F.conv2d(
#
#     537         F.pad(
#
#     538             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#
#    (...)
#
#     545         self.groups,
#
#     546     )
#
# --> 548 return F.conv2d(
#
#     549     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#
#     550 )
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test 2
# best wights from 60 epochs
# MAp50:

# %%
# Path to best.pt downloaded from Colab/Drive
WEIGHTS_PATH = r"C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_runs\yolo11m_bdd100k_v13\weights\best.pt"

# Source: image file, video file, or a folder of images
SOURCE = r"C:\Users\samar\OneDrive\Desktop\Grad Project\Code\Datasets\Dashcam_clips\20260210094954_0060.mp4"

# Output folder (annotated results saved here)
OUTPUT_DIR = r"C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_inference_results"

# %%
CONF_THRESHOLD = 0.25   # minimum confidence to show a detection
IOU_THRESHOLD  = 0.45   # NMS threshold (suppress overlapping boxes)
IMG_SIZE       = 640    # must match training size

# %%
def run_inference():
    # Verify weights exist
    if not Path(WEIGHTS_PATH).exists():
        print(f"[ERROR] Weights not found: {WEIGHTS_PATH}")
        print("        Download best.pt from Google Drive first.")
        return

    if not Path(SOURCE).exists():
        print(f"[ERROR] Source not found: {SOURCE}")
        return

    print(f"Loading model : {WEIGHTS_PATH}")
    model = YOLO(WEIGHTS_PATH)

    print(f"Running inference on: {SOURCE}")
    print("(Running on CPU — video processing will be slower than real-time, that's expected)\n")

    start = time.time()

    results = model.predict(
        source    = SOURCE,
        imgsz     = IMG_SIZE,
        conf      = CONF_THRESHOLD,
        iou       = IOU_THRESHOLD,
        save      = True,               # saves annotated output
        project   = OUTPUT_DIR,
        name      = "run",
        save_txt  = True,               # also saves detections as .txt (useful later for analysis)
        save_conf = True,               # includes confidence scores in .txt files
        stream    = True,               # memory-efficient — important for long videos on CPU
        device    = "cpu",
        verbose   = False,
    )

    # Stream through results (required when stream=True)
    frame_count = 0
    for r in results:
        frame_count += 1

    elapsed = time.time() - start
    fps     = frame_count / elapsed if elapsed > 0 else 0

    print(f"\nDone!")
    print(f"  Frames processed : {frame_count}")
    print(f"  Time taken       : {elapsed:.1f}s")
    print(f"  Average FPS      : {fps:.2f}")
    print(f"  Output saved to  : {OUTPUT_DIR}/run/")


if __name__ == "__main__":
    run_inference()
# Out:
# Loading model : C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_runs\yolo11m_bdd100k_v13\weights\best.pt
# Running inference on: C:\Users\samar\OneDrive\Desktop\Grad Project\Code\Datasets\Dashcam_clips\20260210094954_0060.mp4
# (Running on CPU — video processing will be slower than real-time, that's expected)
#
# Results saved to C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_inference_results\run5
# 1500 labels saved to C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_inference_results\run5\labels
#
# Done!
#   Frames processed : 1500
#   Time taken       : 1930.3s
#   Average FPS      : 0.78
#   Output saved to  : C:\Users\samar\OneDrive\Desktop\Grad Project\Code\tamakkan_inference_results/run/
